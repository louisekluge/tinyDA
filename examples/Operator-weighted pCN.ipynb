# %% [markdown]
# # Operator-weighted pCN: GP Regression

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import multivariate_normal
from scipy.interpolate import interp1d
from scipy.optimize import minimize

import tinyDA as tda

# %%
np.random.seed(456)

# %% [markdown]
# ### Defining the true model and generating some data

# %%
# define some function
def latent_function(x):
    return np.sin(2*np.pi*x)

# %%
# set the number of datapoints and the desired noise
n_data = 10
sigma = 0.1

# draw some random datapoints, evaluate the function and add noise.
x_data = np.random.uniform(size=n_data)
y_data = latent_function(x_data) + np.random.normal(0, sigma, size=x_data.shape[0])

# set the basis.
x = np.linspace(0,1)

# %%
# plot the true function and the datapoints.
plt.plot(x, latent_function(x), c='limegreen')
plt.scatter(x_data, y_data, c='tomato')
plt.show()

# %% [markdown]
# ### Set up the statistical model

# %%
# define the GP kernel (squared exponential)
def kernel(x, y, l):
    return np.exp(-0.5 * (x - y)**2 / l**2)

# %%
# set the length scale and the dimension of the basis.
l = 0.1
n_x = x.shape[0]

# construct the kernel matrix
K = np.zeros((n_x, n_x))
for i in range(n_x):
    for j in range(n_x):
        K[i,j] = kernel(x[i], x[j], l)

# %%
# plot the kernel matrix
plt.imshow(K)
plt.colorbar()
plt.show()

# %%
# set the GP prior
mean_prior = np.zeros(n_x)
my_prior = multivariate_normal(mean=mean_prior, cov=K+1e-3*np.eye(n_x))

# set the Gaussian likelihood
cov_likelihood = sigma**2*np.eye(n_data)
my_loglike = tda.GaussianLogLike(y_data, cov_likelihood)

# %%
# define a model.
def my_model(y):

    # interpolate the GP function
    f = interp1d(x, y)
    
    # evaluate at datapoints
    return f(x_data)

# %%
# initialise the Posterior
my_posterior = tda.Posterior(my_prior, my_loglike, my_model)

# %%
# get the MAP point using minimize, which also approximates the Hessian for free.
_MAP = minimize(lambda x: -my_posterior.create_link(x).posterior, x0=my_prior.rvs())
MAP = _MAP['x']
H_inv = _MAP.hess_inv

# %%
# plot the MAP estimate.
plt.plot(x, MAP, c='k')
plt.scatter(x_data, y_data, c='r')
plt.show()

# %%
# plot the Hessian approximation.
plt.imshow(H_inv)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Set up the proposal

# %%
# preconditioned Crank-Nicolson
#pcn_adaptive = True
#my_proposal = tda.CrankNicolson(adaptive=pcn_adaptive)

# preconditioned Crank-Nicolson
pcn_operator = H_inv
pcn_adaptive = True
my_proposal = tda.OperatorWeightedCrankNicolson(pcn_operator, adaptive=pcn_adaptive)

# %% [markdown]
# ### Sample

# %%
import os
if "CI" in os.environ:
    iterations = 120
    burnin = 20
else:
    iterations = 12000
    burnin = 2000

# %%
my_chains = tda.sample(my_posterior, my_proposal, iterations=iterations, n_chains=2, initial_parameters=MAP, force_sequential=True)
# Out:
# Sampling chain 1/2
# Running chain, α = 0.05:   0%|          | 38/12000 [00:00<02:11, 91.11it/s]
# Running chain, α = 0.31: 100%|██████████| 12000/12000 [01:28<00:00, 135.01it/s]
# Sampling chain 2/2
# Running chain, α = 0.19: 100%|██████████| 12000/12000 [01:34<00:00, 127.39it/s]

# %% [markdown]
# ### Get some diagnostics

# %%
import arviz as az

# %%
idata = tda.to_inference_data(my_chains, burnin=burnin)
# Out:
# /home/louisekluge/miniconda3/envs/tda/lib/python3.12/site-packages/arviz/data/inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(

# %%
az.summary(idata)
# Out:
#       mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0   0.201  0.955  -1.581    1.989      0.042    0.029     523.0    1696.0
# x1   0.286  0.873  -1.290    1.971      0.025    0.018    1193.0    1942.0
# x2   0.321  0.760  -1.023    1.762      0.020    0.014    1470.0    2120.0
# x3   0.445  0.667  -0.715    1.806      0.087    0.062      58.0     405.0
# x4   0.452  0.491  -0.462    1.376      0.016    0.011     963.0    1919.0
# x5   0.530  0.347  -0.151    1.138      0.016    0.011     482.0     886.0
# x6   0.637  0.223   0.204    1.042      0.034    0.024      44.0     688.0
# x7   0.802  0.138   0.541    1.054      0.050    0.037       8.0      29.0
# x8   0.904  0.092   0.731    1.069      0.042    0.033       5.0      16.0
# x9   0.980  0.089   0.810    1.143      0.031    0.023       8.0      19.0
# x10  0.951  0.132   0.709    1.215      0.042    0.031      10.0     228.0
# x11  0.817  0.127   0.576    1.047      0.020    0.014      39.0     499.0
# x12  0.756  0.107   0.554    0.951      0.005    0.004     394.0    1039.0
# x13  0.819  0.294   0.260    1.354      0.013    0.010     496.0     983.0
# x14  0.376  0.396  -0.355    1.141      0.021    0.015     361.0    1188.0
# x15  0.409  0.404  -0.410    1.109      0.034    0.024     153.0    1421.0
# x16  0.222  0.573  -0.842    1.326      0.024    0.017     555.0    1040.0
# x17  0.310  0.626  -0.836    1.545      0.127    0.091      24.0     619.0
# x18  0.091  0.743  -1.327    1.467      0.025    0.018     869.0    1441.0
# x19 -0.119  0.868  -1.625    1.633      0.030    0.021     823.0    1331.0
# x20  0.113  0.641  -1.111    1.308      0.055    0.039     132.0    1092.0
# x21  0.030  0.700  -1.229    1.384      0.068    0.049     103.0     861.0
# x22  0.008  0.706  -1.287    1.381      0.031    0.022     524.0     853.0
# x23  0.218  0.649  -0.919    1.488      0.156    0.112      17.0     115.0
# x24  0.397  0.536  -0.630    1.378      0.116    0.083      21.0     185.0
# x25  0.552  0.521  -0.484    1.493      0.176    0.129       9.0      35.0
# x26  0.284  0.476  -0.632    1.114      0.024    0.017     382.0     813.0
# x27  0.363  0.350  -0.269    1.044      0.089    0.064      15.0     112.0
# x28  0.003  0.220  -0.417    0.395      0.013    0.009     291.0    1072.0
# x29 -0.325  0.141  -0.594   -0.069      0.023    0.016      38.0     360.0
# x30 -0.563  0.076  -0.710   -0.419      0.003    0.002     532.0    1286.0
# x31 -0.720  0.109  -0.919   -0.509      0.007    0.005     216.0     788.0
# x32 -0.688  0.222  -1.053   -0.237      0.081    0.060       8.0      39.0
# x33 -0.619  0.231  -1.041   -0.176      0.078    0.057       9.0      88.0
# x34 -0.652  0.281  -1.141   -0.107      0.107    0.079       7.0      29.0
# x35 -0.689  0.239  -1.118   -0.229      0.063    0.046      14.0     227.0
# x36 -0.749  0.167  -1.073   -0.448      0.057    0.042       9.0      41.0
# x37 -0.955  0.100  -1.125   -0.752      0.018    0.013      31.0     397.0
# x38 -1.010  0.077  -1.152   -0.869      0.010    0.007      54.0     979.0
# x39 -1.026  0.117  -1.241   -0.814      0.060    0.047       4.0      15.0
# x40 -0.882  0.132  -1.102   -0.624      0.051    0.038       7.0      49.0
# x41 -0.708  0.123  -0.922   -0.463      0.039    0.028      10.0     157.0
# x42 -0.556  0.160  -0.819   -0.250      0.078    0.059       5.0      22.0
# x43 -0.428  0.114  -0.633   -0.213      0.009    0.006     168.0    1029.0
# x44 -0.509  0.209  -0.898   -0.117      0.008    0.006     711.0     991.0
# x45 -0.343  0.263  -0.825    0.170      0.012    0.008     525.0    1333.0
# x46 -0.160  0.467  -1.039    0.697      0.028    0.020     269.0    1054.0
# x47 -0.188  0.571  -1.335    0.828      0.025    0.018     508.0    1219.0
# x48  0.214  0.792  -1.188    1.800      0.046    0.032     301.0     879.0
# x49  0.473  0.893  -1.256    2.111      0.044    0.031     415.0    1091.0
#
#      r_hat
# x0    1.02
# x1    1.00
# x2    1.00
# x3    1.03
# x4    1.00
# x5    1.02
# x6    1.05
# x7    1.19
# x8    1.33
# x9    1.18
# x10   1.15
# x11   1.06
# x12   1.02
# x13   1.02
# x14   1.03
# x15   1.03
# x16   1.03
# x17   1.08
# x18   1.01
# x19   1.01
# x20   1.04
# x21   1.03
# x22   1.01
# x23   1.09
# x24   1.08
# x25   1.16
# x26   1.01
# x27   1.09
# x28   1.01
# x29   1.06
# x30   1.01
# x31   1.01
# x32   1.19
# x33   1.16
# x34   1.21
# x35   1.10
# x36   1.16
# x37   1.06
# x38   1.04
# x39   1.45
# x40   1.22
# x41   1.14
# x42   1.36
# x43   1.03
# x44   1.01
# x45   1.01
# x46   1.03
# x47   1.01
# x48   1.02
# x49   1.01

# %%
az.plot_trace(idata)
plt.show()
# Out:
# /home/louisekluge/miniconda3/envs/tda/lib/python3.12/site-packages/arviz/plots/traceplot.py:223: UserWarning: rcParams['plot.max_subplots'] (20) is smaller than the number of variables to plot (50), generating only 20 plots
#   warnings.warn(

# %%
parameters = np.array([link.parameters for link in my_chains['chain_0'][burnin:] + my_chains['chain_1'][burnin:]])

# %%
plt.plot(x, latent_function(x), c='limegreen', linewidth=2)
plt.scatter(x_data, y_data, c='r')
for i in range(1000):
    idx = np.random.randint(parameters.shape[0])
    plt.plot(x, parameters[idx,:], c='k', alpha=0.01, zorder=0)
plt.show()
